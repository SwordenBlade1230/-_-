# %% [markdown]
# ## 載入函式庫

# %%
import tensorflow as tf
from keras_segmentation.models.unet import resnet50_unet
import keras
import numpy as np
import os
import cv2
import time
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 解決 TensorFlow 2.0 程式出現 cuDNN failed to initialize 錯誤問題
#
# https://davistseng.blogspot.com/2019/11/tensorflow-2.html

# %%
def solve_cudnn_error():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)

solve_cudnn_error()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## 建立腎臟區域預測模型
#
# 資料集：DATA
# * batch_size = 2
# * 腫瘤視為腎臟
# * 重新調整case160的影像大小
# * WW = 600, WL = 100
# * Base Model: Resnet-50
# * Segmentation Model: U-Net

# %% [markdown]
# ### 查看模型架構

# %%
model = resnet50_unet(n_classes = 2, input_height = 512, input_width = 512)
model.summary()

# %% [markdown]
# ### 模型參數設定

# %%
dataset_dir = 'DATA\\WW600WL100'
input_size = 512
epochs = 100
batch_size = 2 # default value
steps_per_epoch = 512 # default value

# %% [markdown]
# ### 訓練模型
#
# 目前用來評估模型表現的指標：
# * average dice score per case
# * average recall
# * average precision
# * global dice score

# %%
model_dir = os.path.join(dataset_dir, 'model')

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print('-----建立新資料夾：' + model_dir + '-----') 

st = time.time()

target_dataset = dataset_dir
print(f'########## 即將用該資料集進行訓練：{target_dataset} ##########')

model_name = 'resnet50_unet'
checkpoints_path = os.path.join(model_dir, model_name)

keras.backend.clear_session() # 銷毀當前的TF，避免舊模型/網路層混亂，並減緩內存
model = resnet50_unet(n_classes = 2, input_height = input_size, input_width = input_size)

model.train(
    train_images = os.path.join(dataset_dir, 'train', 'images'),
    train_annotations = os.path.join(dataset_dir, 'train', 'annotations_tumor as kidney'),
    epochs = epochs, # default = 5
    batch_size = batch_size, # default = 2
    steps_per_epoch = steps_per_epoch, # default = 512
    verify_dataset = False, # 當資料量很多時檢驗資料集會花很多時間
    checkpoints_path = checkpoints_path
)

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
print()
# Out:
# -----建立新資料夾：DATA_0811_2\WW600WL100\model_resnet50_unet_bs4-----
# ########## 即將用該資料集進行訓練：DATA_0811_2\WW600WL100 ##########
# Epoch 1/100
# 512/512 [==============================] - 269s 525ms/step - loss: 0.0898 - accuracy: 0.9730
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.0
# Epoch 2/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0099 - accuracy: 0.9969
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.1
# Epoch 3/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0068 - accuracy: 0.9979
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.2
# Epoch 4/100
# 512/512 [==============================] - 241s 472ms/step - loss: 0.0044 - accuracy: 0.9986
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.3
# Epoch 5/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0032 - accuracy: 0.9989
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.4
# Epoch 6/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0030 - accuracy: 0.9990
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.5
# Epoch 7/100
# 512/512 [==============================] - 241s 470ms/step - loss: 0.0031 - accuracy: 0.9990
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.6
# Epoch 8/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0022 - accuracy: 0.9992
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.7
# Epoch 9/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.8
# Epoch 10/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0016 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.9
# Epoch 11/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0022 - accuracy: 0.9992
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.10
# Epoch 12/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0018 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.11
# Epoch 13/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0019 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.12
# Epoch 14/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0015 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.13
# Epoch 15/100
# 512/512 [==============================] - 241s 470ms/step - loss: 0.0015 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.14
# Epoch 16/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.15
# Epoch 17/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0015 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.16
# Epoch 18/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.17
# Epoch 19/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.18
# Epoch 20/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.19
# Epoch 21/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.20
# Epoch 22/100
# 512/512 [==============================] - 241s 470ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.21
# Epoch 23/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.22
# Epoch 24/100
# 512/512 [==============================] - 241s 472ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.23
# Epoch 25/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.24
# Epoch 26/100
# 512/512 [==============================] - 242s 473ms/step - loss: 9.6914e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.25
# Epoch 27/100
# 512/512 [==============================] - 241s 472ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.26
# Epoch 28/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.27
# Epoch 29/100
# 512/512 [==============================] - 242s 472ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.28
# Epoch 30/100
# 512/512 [==============================] - 242s 472ms/step - loss: 9.0686e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.29
# Epoch 31/100
# 512/512 [==============================] - 241s 472ms/step - loss: 9.5302e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.30
# Epoch 32/100
# 512/512 [==============================] - 241s 471ms/step - loss: 9.4599e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.31
# Epoch 33/100
# 512/512 [==============================] - 241s 471ms/step - loss: 9.4146e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.32
# Epoch 34/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.33
# Epoch 35/100
# 512/512 [==============================] - 242s 472ms/step - loss: 9.0052e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.34
# Epoch 36/100
# 512/512 [==============================] - 241s 471ms/step - loss: 8.4389e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.35
# Epoch 37/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.3684e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.36
# Epoch 38/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.9607e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.37
# Epoch 39/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.9047e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.38
# Epoch 40/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.4393e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.39
# Epoch 41/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.9131e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.40
# Epoch 42/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.8694e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.41
# Epoch 43/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.9764e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.42
# Epoch 44/100
# 512/512 [==============================] - 241s 471ms/step - loss: 8.9860e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.43
# Epoch 45/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.2921e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.44
# Epoch 46/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.3153e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.45
# Epoch 47/100
# 512/512 [==============================] - 241s 471ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.46
# Epoch 48/100
# 512/512 [==============================] - 242s 473ms/step - loss: 7.8483e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.47
# Epoch 49/100
# 512/512 [==============================] - 242s 472ms/step - loss: 8.4448e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.48
# Epoch 50/100
# 512/512 [==============================] - 241s 472ms/step - loss: 8.7217e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.49
# Epoch 51/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.5901e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.50
# Epoch 52/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.1291e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.51
# Epoch 53/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.6104e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.52
# Epoch 54/100
# 512/512 [==============================] - 241s 471ms/step - loss: 8.0768e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.53
# Epoch 55/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.8016e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.54
# Epoch 56/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.1438e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.55
# Epoch 57/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.9318e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.56
# Epoch 58/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.5555e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.57
# Epoch 59/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.8140e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.58
# Epoch 60/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.8217e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.59
# Epoch 61/100
# 512/512 [==============================] - 242s 473ms/step - loss: 7.3854e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.60
# Epoch 62/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.1438e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.61
# Epoch 63/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.3050e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.62
# Epoch 64/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.4439e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.63
# Epoch 65/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.6632e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.64
# Epoch 66/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.1946e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.65
# Epoch 67/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.6183e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.66
# Epoch 68/100
# 512/512 [==============================] - 241s 471ms/step - loss: 6.6255e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.67
# Epoch 69/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.0239e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.68
# Epoch 70/100
# 512/512 [==============================] - 241s 471ms/step - loss: 7.1442e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.69
# Epoch 71/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.1077e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.70
# Epoch 72/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.4500e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.71
# Epoch 73/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.7427e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.72
# Epoch 74/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.2502e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.73
# Epoch 75/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.8615e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.74
# Epoch 76/100
# 512/512 [==============================] - 242s 472ms/step - loss: 7.0752e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.75
# Epoch 77/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.2023e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.76
# Epoch 78/100
# 512/512 [==============================] - 241s 471ms/step - loss: 6.6320e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.77
# Epoch 79/100
# 512/512 [==============================] - 242s 473ms/step - loss: 6.6002e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.78
# Epoch 80/100
# 512/512 [==============================] - 241s 472ms/step - loss: 6.7866e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.79
# Epoch 81/100
# 512/512 [==============================] - 241s 472ms/step - loss: 7.1354e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.80
# Epoch 82/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.5996e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.81
# Epoch 83/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.0336e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.82
# Epoch 84/100
# 512/512 [==============================] - 241s 471ms/step - loss: 6.1640e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.83
# Epoch 85/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.7698e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.84
# Epoch 86/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.4327e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.85
# Epoch 87/100
# 512/512 [==============================] - 243s 474ms/step - loss: 6.3413e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.86
# Epoch 88/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.1149e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.87
# Epoch 89/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.0068e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.88
# Epoch 90/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.5202e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.89
# Epoch 91/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.5960e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.90
# Epoch 92/100
# 512/512 [==============================] - 242s 473ms/step - loss: 6.1790e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.91
# Epoch 93/100
# 512/512 [==============================] - 242s 473ms/step - loss: 5.6129e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.92
# Epoch 94/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.5401e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.93
# Epoch 95/100
# 512/512 [==============================] - 242s 473ms/step - loss: 6.2354e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.94
# Epoch 96/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.4566e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.95
# Epoch 97/100
# 512/512 [==============================] - 242s 472ms/step - loss: 6.4913e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.96
# Epoch 98/100
# 512/512 [==============================] - 242s 472ms/step - loss: 5.6779e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.97
# Epoch 99/100
# 512/512 [==============================] - 242s 472ms/step - loss: 5.7236e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.98
# Epoch 100/100
# 512/512 [==============================] - 242s 472ms/step - loss: 5.8704e-04 - accuracy: 0.9998
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.99
# 花費時間(秒)：24468.138919115067

# %% [markdown]
# ## 對測試集進行預測，並生成評估指標

# %%
from evaluate import *

st = time.time()

result = evaluate_model(
    image_dir = os.path.join(dataset_dir, 'test', 'images'), 
    label_dir = os.path.join(dataset_dir, 'test', 'annotations_tumor as kidney'), 
    checkpoints_path = 'DATA\\WW600WL100\\model\\resnet50_unet', # 用套件建立出來的模型儲存路徑
    calculate_predicting_indicators = True, # 是否計算並回傳評估指標
    output_predicted_result = False,  # 是否輸出模型預測結果
    segment_out_predicted_region_from_original_images = False, # 是否根據模型預測結果從原始影像中切割出預測區域 
    roi_description = 'tumor as kidney',
    preds = None)

print('測試集預測結果：')
print(f'average Dice score per case of kidney: {result[0]: .4f}')
print(f'average recall of kidney: {result[1]: .4f}')
print(f'average precision of kidney: {result[2]: .4f}')
print(f'global dice score of kidney: {result[3]: .4f}')
print('')
print('混淆矩陣：')
print(f'True Positive: {result[-4]}')
print(f'False Positive: {result[-3]}')
print(f'False Negative: {result[-2]}')
print(f'True Negative: {result[-1]}')

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
# Out:
# ----------生成模型預測結果----------
# loaded weights  DATA_0811_2\WW600WL100\model_resnet50_unet_bs4\resnet50_unet_padding0.99
# 100%|████████████████████████████████████████████████████████████████████████████| 12656/12656 [14:48<00:00, 14.25it/s]
# ----------開始計算各項預測指標----------
# 目前進度：第500張照片
# 目前進度：第1000張照片
# 目前進度：第1500張照片
# 目前進度：第2000張照片
# 目前進度：第2500張照片
# 目前進度：第3000張照片
# 目前進度：第3500張照片
# 目前進度：第4000張照片
# 目前進度：第4500張照片
# 目前進度：第5000張照片
# 目前進度：第5500張照片
# 目前進度：第6000張照片
# 目前進度：第6500張照片
# 目前進度：第7000張照片
# 目前進度：第7500張照片
# 目前進度：第8000張照片
# 目前進度：第8500張照片
# 目前進度：第9000張照片
# 目前進度：第9500張照片
# 目前進度：第10000張照片
# 目前進度：第10500張照片
# 目前進度：第11000張照片
# 目前進度：第11500張照片
# 目前進度：第12000張照片
# 目前進度：第12500張照片
# total case number: 12656
# 訓練集預測結果：
# average Dice score per case of kidney:  0.9650
# average recall of kidney:  0.9587
# average precision of kidney:  0.9726
# global dice score of kidney:  0.9605
# 花費時間(秒)：1585.6040244102478

# %%
f = open("DATA\\patient indices of testing set - KiTS.txt", "r")
test_patient_idx = f.read().splitlines()
f.close()

dice_score_list = result[5]
print('測試集各病患的 Dice score:')
for idx, i in enumerate(dice_score_list):
    print(f'case{test_patient_idx[idx]}: {i: .4f}')
