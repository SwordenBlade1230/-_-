# %% [markdown]
# ## 載入函式庫

# %%
import tensorflow as tf
from keras_segmentation.models.unet import resnet50_unet
import keras
import numpy as np
import os
import cv2
import time
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 解決 TensorFlow 2.0 程式出現 cuDNN failed to initialize 錯誤問題
#
# https://davistseng.blogspot.com/2019/11/tensorflow-2.html

# %%
def solve_cudnn_error():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)

solve_cudnn_error()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## 第一次建模
#
# 資料集：DATA_0811_1
# * **腫瘤視為背景**
# * 去除case180、203，重新調整case160的影像大小
# * 沒有做退縮
# * WW = 600, WL = 100
# * Base Model: Resnet-50
# * Segmentation Model: U-Net

# %%
result_list = [] # 用來記錄各次建模的結果

# %% [markdown]
# ### 查看模型架構

# %%
model = resnet50_unet(n_classes = 2, input_height = 512, input_width = 512)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 518, 518, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 256, 256, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 256, 256, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 127, 127, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 127, 127, 64) 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 127, 127, 64) 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 127, 127, 64) 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 127, 127, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 127, 127, 64) 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 127, 127, 64) 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 127, 127, 256 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 127, 127, 256 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 127, 127, 256 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 127, 127, 256 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 127, 127, 256 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 127, 127, 256 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 127, 127, 64) 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 127, 127, 64) 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 127, 127, 64) 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 127, 127, 64) 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 127, 127, 64) 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 127, 127, 64) 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 127, 127, 256 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 127, 127, 256 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 127, 127, 256 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 127, 127, 256 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 127, 127, 64) 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 127, 127, 64) 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 127, 127, 64) 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 127, 127, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 127, 127, 64) 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 127, 127, 64) 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 127, 127, 256 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 127, 127, 256 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 127, 127, 256 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 127, 127, 256 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 64, 64, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 64, 64, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 64, 64, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 64, 64, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 64, 64, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 64, 64, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 64, 64, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 64, 64, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 64, 64, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 64, 64, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 64, 64, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 64, 64, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 32, 32, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 32, 32, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 32, 32, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 32, 32, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 32, 32, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 32, 32, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 32, 32, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 32, 32, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 32, 32, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 32, 32, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 32, 32, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 32, 32, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 32, 32, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 34, 34, 1024) 0           activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 512)  4719104     zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 1024) 0           up_sampling2d_1[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 66, 66, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 256)  2359552     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 129, 129, 256 0           activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 256 0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 512 0           up_sampling2d_2[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 130, 130, 512 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 589952      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 192 0           up_sampling2d_3[0][0]
#                                                                  conv1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 258, 258, 192 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 110656      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 514, 514, 64) 0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 64) 36928       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512, 512, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 512, 2)  1154        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 262144, 2)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 262144, 2)    0           reshape_1[0][0]
# ==================================================================================================
# Total params: 16,410,626
# Trainable params: 16,377,986
# Non-trainable params: 32,640
# __________________________________________________________________________________________________

# %% [markdown]
# ### 模型參數設定

# %%
dataset_dir = 'DATA_0811_1\\WW600WL100'
input_size = 512
epochs = 100
steps_per_epoch = 512

# %% [markdown]
# ### 訓練及評估模型
#
# 目前用來評估模型表現的指標：
# * average dice score per case
# * average recall
# * average precision
# * global dice score

# %%
model_dir = os.path.join(dataset_dir, 'model_resnet50_unet')

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print('-----建立新資料夾：' + model_dir + '-----') 

st = time.time()

target_dataset = dataset_dir
print(f'########## 即將用該資料集進行訓練：{target_dataset} ##########')

model_name = 'resnet50_unet_padding0'
checkpoints_path = os.path.join(model_dir, model_name)

keras.backend.clear_session() # 銷毀當前的TF，避免舊模型/網路層混亂，並減緩內存
model = resnet50_unet(n_classes = 2, input_height = input_size, input_width = input_size)

model.train(
    train_images = os.path.join(dataset_dir, 'train', 'images'),
    train_annotations = os.path.join(dataset_dir, 'train', 'annotations_kidney only'),
    epochs = epochs, # default = 5
    steps_per_epoch = steps_per_epoch, # default = 512
    verify_dataset = False, # 當資料量很多時檢驗資料集會花很多時間
    checkpoints_path = checkpoints_path
)

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
print()
# Out:
# -----建立新資料夾：DATA_0811_1\WW600WL100\model_resnet50_unet-----
# ########## 即將用該資料集進行訓練：DATA_0811_1\WW600WL100 ##########
# Epoch 1/100
# 512/512 [==============================] - 183s 357ms/step - loss: 0.0932 - accuracy: 0.9784
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.0
# Epoch 2/100
# 512/512 [==============================] - 148s 289ms/step - loss: 0.0073 - accuracy: 0.9978
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.1
# Epoch 3/100
# 512/512 [==============================] - 148s 289ms/step - loss: 0.0066 - accuracy: 0.9979
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.2
# Epoch 4/100
# 512/512 [==============================] - 146s 285ms/step - loss: 0.0052 - accuracy: 0.9984
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.3
# Epoch 5/100
# 512/512 [==============================] - 145s 284ms/step - loss: 0.0044 - accuracy: 0.9985
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.4
# Epoch 6/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0042 - accuracy: 0.9986
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.5
# Epoch 7/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0033 - accuracy: 0.9989
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.6
# Epoch 8/100
# 512/512 [==============================] - 145s 284ms/step - loss: 0.0032 - accuracy: 0.9989
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.7
# Epoch 9/100
# 512/512 [==============================] - 145s 284ms/step - loss: 0.0029 - accuracy: 0.9990
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.8
# Epoch 10/100
# 512/512 [==============================] - 145s 284ms/step - loss: 0.0032 - accuracy: 0.9989
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.9
# Epoch 11/100
# 512/512 [==============================] - 145s 284ms/step - loss: 0.0026 - accuracy: 0.9991
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.10
# Epoch 12/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0029 - accuracy: 0.9990
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.11
# Epoch 13/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0027 - accuracy: 0.9990
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.12
# Epoch 14/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0028 - accuracy: 0.9990
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.13
# Epoch 15/100
# 512/512 [==============================] - 144s 282ms/step - loss: 0.0026 - accuracy: 0.9991
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.14
# Epoch 16/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0024 - accuracy: 0.9992
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.15
# Epoch 17/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0021 - accuracy: 0.9992
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.16
# Epoch 18/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.17
# Epoch 19/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0026 - accuracy: 0.9991
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.18
# Epoch 20/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0021 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.19
# Epoch 21/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0022 - accuracy: 0.9992
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.20
# Epoch 22/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.21
# Epoch 23/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0024 - accuracy: 0.9991
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.22
# Epoch 24/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.23
# Epoch 25/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0022 - accuracy: 0.9992
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.24
# Epoch 26/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.25
# Epoch 27/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.26
# Epoch 28/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0015 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.27
# Epoch 29/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0018 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.28
# Epoch 30/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0015 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.29
# Epoch 31/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.30
# Epoch 32/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.31
# Epoch 33/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0016 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.32
# Epoch 34/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.33
# Epoch 35/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0018 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.34
# Epoch 36/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0018 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.35
# Epoch 37/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0016 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.36
# Epoch 38/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0018 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.37
# Epoch 39/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0015 - accuracy: 0.9994
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.38
# Epoch 40/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.39
# Epoch 41/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.40
# Epoch 42/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.41
# Epoch 43/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.42
# Epoch 44/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0015 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.43
# Epoch 45/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.44
# Epoch 46/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.45
# Epoch 47/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.46
# Epoch 48/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.47
# Epoch 49/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.48
# Epoch 50/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.49
# Epoch 51/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.50
# Epoch 52/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.51
# Epoch 53/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.52
# Epoch 54/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.53
# Epoch 55/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.54
# Epoch 56/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.55
# Epoch 57/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.56
# Epoch 58/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.57
# Epoch 59/100
# 512/512 [==============================] - 145s 283ms/step - loss: 9.9906e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.58
# Epoch 60/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.59
# Epoch 61/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.60
# Epoch 62/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.61
# Epoch 63/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.62
# Epoch 64/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.63
# Epoch 65/100
# 512/512 [==============================] - 145s 283ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.64
# Epoch 66/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0012 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.65
# Epoch 67/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.66
# Epoch 68/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.67
# Epoch 69/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.68
# Epoch 70/100
# 512/512 [==============================] - 144s 282ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.69
# Epoch 71/100
# 512/512 [==============================] - 145s 282ms/step - loss: 9.2595e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.70
# Epoch 72/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.4416e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.71
# Epoch 73/100
# 512/512 [==============================] - 145s 283ms/step - loss: 9.2435e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.72
# Epoch 74/100
# 512/512 [==============================] - 144s 282ms/step - loss: 9.1248e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.73
# Epoch 75/100
# 512/512 [==============================] - 145s 282ms/step - loss: 9.1785e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.74
# Epoch 76/100
# 512/512 [==============================] - 145s 282ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.75
# Epoch 77/100
# 512/512 [==============================] - 145s 282ms/step - loss: 9.5236e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.76
# Epoch 78/100
# 512/512 [==============================] - 144s 282ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.77
# Epoch 79/100
# 512/512 [==============================] - 145s 282ms/step - loss: 8.7956e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.78
# Epoch 80/100
# 512/512 [==============================] - 145s 282ms/step - loss: 8.3096e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.79
# Epoch 81/100
# 512/512 [==============================] - 145s 283ms/step - loss: 7.8188e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.80
# Epoch 82/100
# 512/512 [==============================] - 145s 284ms/step - loss: 9.0663e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.81
# Epoch 83/100
# 512/512 [==============================] - 145s 283ms/step - loss: 7.6788e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.82
# Epoch 84/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.9728e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.83
# Epoch 85/100
# 512/512 [==============================] - 145s 283ms/step - loss: 9.5547e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.84
# Epoch 86/100
# 512/512 [==============================] - 145s 283ms/step - loss: 9.6024e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.85
# Epoch 87/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.2955e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.86
# Epoch 88/100
# 512/512 [==============================] - 145s 283ms/step - loss: 9.9053e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.87
# Epoch 89/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.6107e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.88
# Epoch 90/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.3391e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.89
# Epoch 91/100
# 512/512 [==============================] - 145s 283ms/step - loss: 7.7348e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.90
# Epoch 92/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.7102e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.91
# Epoch 93/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.4142e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.92
# Epoch 94/100
# 512/512 [==============================] - 145s 282ms/step - loss: 8.9667e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.93
# Epoch 95/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.3552e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.94
# Epoch 96/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.8218e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.95
# Epoch 97/100
# 512/512 [==============================] - 145s 282ms/step - loss: 9.8276e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.96
# Epoch 98/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.6373e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.97
# Epoch 99/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.7873e-04 - accuracy: 0.9996
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.98
# Epoch 100/100
# 512/512 [==============================] - 145s 283ms/step - loss: 8.8081e-04 - accuracy: 0.9997
# saved  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.99
# 花費時間(秒)：14877.897794008255

# %%
from evaluate import *

st = time.time()

result = evaluate_model(
    image_dir = os.path.join(dataset_dir, 'test', 'images'), 
    label_dir = os.path.join(dataset_dir, 'test', 'annotations_kidney only'), 
    checkpoints_path = 'DATA_0811_1\\WW600WL100\\model_resnet50_unet\\resnet50_unet_padding0',
    calculate_predicting_indicators = True,
    output_predicted_result = False, 
    segment_out_predicted_region_from_original_images = False, 
    roi_name = 'kidney', 
    preds = None)

print('訓練集預測結果：')
print(f'average Dice score per case of kidney: {result[0]: .4f}')
print(f'average recall of kidney: {result[1]: .4f}')
print(f'average precision of kidney: {result[2]: .4f}')
print(f'global dice score of kidney: {result[3]: .4f}')
result_list.append(result)

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
print()
# Out:
# ----------生成模型預測結果----------
# loaded weights  DATA_0811_1\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.99
# 100%|████████████████████████████████████████████████████████████████████████████| 12656/12656 [13:38<00:00, 15.46it/s]
# ----------開始計算各項預測指標----------
# 目前進度：第500張照片
# 目前進度：第1000張照片
# 目前進度：第1500張照片
# 目前進度：第2000張照片
# 目前進度：第2500張照片
# 目前進度：第3000張照片
# 目前進度：第3500張照片
# 目前進度：第4000張照片
# 目前進度：第4500張照片
# 目前進度：第5000張照片
# 目前進度：第5500張照片
# 目前進度：第6000張照片
# 目前進度：第6500張照片
# 目前進度：第7000張照片
# 目前進度：第7500張照片
# 目前進度：第8000張照片
# 目前進度：第8500張照片
# 目前進度：第9000張照片
# 目前進度：第9500張照片
# 目前進度：第10000張照片
# 目前進度：第10500張照片
# 目前進度：第11000張照片
# 目前進度：第11500張照片
# 目前進度：第12000張照片
# 目前進度：第12500張照片
# total case number: 12656
# 訓練集預測結果：
# average Dice score per case of kidney:  0.9443
# average recall of kidney:  0.9423
# average precision of kidney:  0.9477
# global dice score of kidney:  0.9479
# 花費時間(秒)：1514.3356366157532

# %%
# st = time.time()

# preds = result[4]

# _ = evaluate_model(
#     image_dir = os.path.join(dataset_dir, 'test', 'images'), 
#     label_dir = os.path.join(dataset_dir, 'test', 'annotations_kidney only'), 
#     checkpoints_path = 'DATA_0811_1\\WW600WL100\\\model_resnet50_unet\\resnet50_unet_padding0',
#     calculate_predicting_indicators = False,
#     output_predicted_result = True, 
#     segment_out_predicted_region_from_original_images = True, 
#     roi_name = 'kidney', 
#     preds = preds
# )

# ed = time.time()
# spend_time = ed - st
# print('花費時間(秒)：' + str(spend_time))
# print()

# %% [markdown]
# ## 隨機印出幾張CT影像的預測結果(訓練集)
#
# 由於之後要把訓練集中的腎臟影像作為第二階段的輸入，因此這裡是印出訓練集的預測結果(測試集在這裡只是評估模型是否能夠準確預測腎臟區域)

# %%
# from evaluate import *
# show_result(
#     target_dataset_base_dir = 'DATA_0811_1\\WW600WL100\\train',
#     result_num = 10,
#     roi_name = 'kidney', 
#     roi_name_chinese = '腎臟',
#     show_predicted_result = True,
#     show_segmentation_result = True, 
#     image_scale = 4)

# %% [markdown]
# ## 隨機印出幾張CT影像的預測結果(測試集)

# %%
from evaluate import *
show_result(
    target_dataset_base_dir = 'DATA_0811_1\\WW600WL100\\test',
    result_num = 10,
    roi_name = 'kidney', 
    roi_name_chinese = '腎臟',
    show_predicted_result = True,
    show_segmentation_result = True, 
    image_scale = 4)

# %% [markdown]
# ## 第二次建模
#
# 資料集：DATA_0811_2
# * **腫瘤視為正常腎臟**
# * 去除case180、203，重新調整case160的影像大小
# * 沒有做退縮
# * WW = 600, WL = 100
# * Base Model: Resnet-50
# * Segmentation Model: U-Net

# %% [markdown]
# ### 模型參數設定

# %%
dataset_dir = 'DATA_0811_2\\WW600WL100'
input_size = 512
epochs = 100
steps_per_epoch = 512

# %% [markdown]
# ### 訓練及評估模型
#
# 目前用來評估模型表現的指標：
# * average dice score per case
# * average recall
# * average precision
# * global dice score

# %%
model_dir = os.path.join(dataset_dir, 'model_resnet50_unet')

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print('-----建立新資料夾：' + model_dir + '-----') 

st = time.time()

target_dataset = dataset_dir
print(f'########## 即將用該資料集進行訓練：{target_dataset} ##########')

model_name = 'resnet50_unet_padding0'
checkpoints_path = os.path.join(model_dir, model_name)

keras.backend.clear_session() # 銷毀當前的TF，避免舊模型/網路層混亂，並減緩內存
model = resnet50_unet(n_classes = 2, input_height = input_size, input_width = input_size)

model.train(
    train_images = os.path.join(dataset_dir, 'train', 'images'),
    train_annotations = os.path.join(dataset_dir, 'train', 'annotations_tumor as kidney'),
    epochs = epochs, # default = 5
    steps_per_epoch = steps_per_epoch, # default = 512
    verify_dataset = False, # 當資料量很多時檢驗資料集會花很多時間
    checkpoints_path = checkpoints_path
)

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
print()
# Out:
# -----建立新資料夾：DATA_0811_2\WW600WL100\model_resnet50_unet-----
# ########## 即將用該資料集進行訓練：DATA_0811_2\WW600WL100 ##########
# Epoch 1/100
# 512/512 [==============================] - 186s 363ms/step - loss: 0.1013 - accuracy: 0.9723
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.0
# Epoch 2/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0151 - accuracy: 0.9955
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.1
# Epoch 3/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0094 - accuracy: 0.9971
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.2
# Epoch 4/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0070 - accuracy: 0.9979
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.3
# Epoch 5/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0055 - accuracy: 0.9982
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.4
# Epoch 6/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0075 - accuracy: 0.9977
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.5
# Epoch 7/100
# 512/512 [==============================] - 163s 319ms/step - loss: 0.0041 - accuracy: 0.9987
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.6
# Epoch 8/100
# 512/512 [==============================] - 162s 316ms/step - loss: 0.0053 - accuracy: 0.9984
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.7
# Epoch 9/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0044 - accuracy: 0.9986
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.8
# Epoch 10/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0026 - accuracy: 0.9991
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.9
# Epoch 11/100
# 512/512 [==============================] - 162s 316ms/step - loss: 0.0030 - accuracy: 0.9990
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.10
# Epoch 12/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0026 - accuracy: 0.9991
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.11
# Epoch 13/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0024 - accuracy: 0.9991
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.12
# Epoch 14/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0043 - accuracy: 0.9986
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.13
# Epoch 15/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0025 - accuracy: 0.9991
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.14
# Epoch 16/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0019 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.15
# Epoch 17/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0020 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.16
# Epoch 18/100
# 512/512 [==============================] - 162s 315ms/step - loss: 0.0023 - accuracy: 0.9992
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.17
# Epoch 19/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0022 - accuracy: 0.9992
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.18
# Epoch 20/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0035 - accuracy: 0.9989
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.19
# Epoch 21/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0024 - accuracy: 0.9991
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.20
# Epoch 22/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0018 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.21
# Epoch 23/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.22
# Epoch 24/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0019 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.23
# Epoch 25/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.24
# Epoch 26/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0023 - accuracy: 0.9992
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.25
# Epoch 27/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0019 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.26
# Epoch 28/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0021 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.27
# Epoch 29/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0017 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.28
# Epoch 30/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0016 - accuracy: 0.9994
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.29
# Epoch 31/100
# 512/512 [==============================] - 162s 316ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.30
# Epoch 32/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.31
# Epoch 33/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.32
# Epoch 34/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0021 - accuracy: 0.9993
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.33
# Epoch 35/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.34
# Epoch 36/100
# 512/512 [==============================] - 162s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.35
# Epoch 37/100
# 512/512 [==============================] - 162s 315ms/step - loss: 0.0014 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.36
# Epoch 38/100
# 512/512 [==============================] - 162s 316ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.37
# Epoch 39/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0015 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.38
# Epoch 40/100
# 512/512 [==============================] - 162s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.39
# Epoch 41/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.40
# Epoch 42/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.9752e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.41
# Epoch 43/100
# 512/512 [==============================] - 162s 315ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.42
# Epoch 44/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.43
# Epoch 45/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.44
# Epoch 46/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.45
# Epoch 47/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.46
# Epoch 48/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.47
# Epoch 49/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.48
# Epoch 50/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.49
# Epoch 51/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.50
# Epoch 52/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0013 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.51
# Epoch 53/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.52
# Epoch 54/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.9896e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.53
# Epoch 55/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.3846e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.54
# Epoch 56/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.7773e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.55
# Epoch 57/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0010 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.56
# Epoch 58/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.7388e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.57
# Epoch 59/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0011 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.58
# Epoch 60/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.9973e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.59
# Epoch 61/100
# 512/512 [==============================] - 161s 315ms/step - loss: 0.0012 - accuracy: 0.9995
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.60
# Epoch 62/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.1356e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.61
# Epoch 63/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.8700e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.62
# Epoch 64/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.2105e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.63
# Epoch 65/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.5640e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.64
# Epoch 66/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.1655e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.65
# Epoch 67/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.3037e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.66
# Epoch 68/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.8827e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.67
# Epoch 69/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.6144e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.68
# Epoch 70/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.0548e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.69
# Epoch 71/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.8652e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.70
# Epoch 72/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.0135e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.71
# Epoch 73/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.5537e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.72
# Epoch 74/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.9194e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.73
# Epoch 75/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.3455e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.74
# Epoch 76/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.5421e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.75
# Epoch 77/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.0499e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.76
# Epoch 78/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.4556e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.77
# Epoch 79/100
# 512/512 [==============================] - 162s 316ms/step - loss: 7.1037e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.78
# Epoch 80/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.2270e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.79
# Epoch 81/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.2684e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.80
# Epoch 82/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.7584e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.81
# Epoch 83/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.3549e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.82
# Epoch 84/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.8055e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.83
# Epoch 85/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.6804e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.84
# Epoch 86/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.0653e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.85
# Epoch 87/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.6716e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.86
# Epoch 88/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.4187e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.87
# Epoch 89/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.0838e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.88
# Epoch 90/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.7408e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.89
# Epoch 91/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.0468e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.90
# Epoch 92/100
# 512/512 [==============================] - 161s 315ms/step - loss: 9.0545e-04 - accuracy: 0.9996
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.91
# Epoch 93/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.2474e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.92
# Epoch 94/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.6742e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.93
# Epoch 95/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.6617e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.94
# Epoch 96/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.4032e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.95
# Epoch 97/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.0468e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.96
# Epoch 98/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.1147e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.97
# Epoch 99/100
# 512/512 [==============================] - 161s 315ms/step - loss: 8.4223e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.98
# Epoch 100/100
# 512/512 [==============================] - 161s 315ms/step - loss: 7.3824e-04 - accuracy: 0.9997
# saved  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.99
# 花費時間(秒)：16486.463507175446

# %%
from evaluate import *

st = time.time()

result = evaluate_model(
    image_dir = os.path.join(dataset_dir, 'test', 'images'), 
    label_dir = os.path.join(dataset_dir, 'test', 'annotations_tumor as kidney'), 
    checkpoints_path = 'DATA_0811_2\\WW600WL100\\model_resnet50_unet\\resnet50_unet_padding0',
    calculate_predicting_indicators = True,
    output_predicted_result = False, 
    segment_out_predicted_region_from_original_images = False, 
    roi_name = 'kidney', 
    preds = None)

print('訓練集預測結果：')
print(f'average Dice score per case of kidney: {result[0]: .4f}')
print(f'average recall of kidney: {result[1]: .4f}')
print(f'average precision of kidney: {result[2]: .4f}')
print(f'global dice score of kidney: {result[3]: .4f}')
result_list.append(result)

ed = time.time()
spend_time = ed - st
print('花費時間(秒)：' + str(spend_time))
print()
# Out:
# ----------生成模型預測結果----------
# loaded weights  DATA_0811_2\WW600WL100\model_resnet50_unet\resnet50_unet_padding0.99
# 100%|████████████████████████████████████████████████████████████████████████████| 12656/12656 [13:35<00:00, 15.52it/s]
# ----------開始計算各項預測指標----------
# 目前進度：第500張照片
# 目前進度：第1000張照片
# 目前進度：第1500張照片
# 目前進度：第2000張照片
# 目前進度：第2500張照片
# 目前進度：第3000張照片
# 目前進度：第3500張照片
# 目前進度：第4000張照片
# 目前進度：第4500張照片
# 目前進度：第5000張照片
# 目前進度：第5500張照片
# 目前進度：第6000張照片
# 目前進度：第6500張照片
# 目前進度：第7000張照片
# 目前進度：第7500張照片
# 目前進度：第8000張照片
# 目前進度：第8500張照片
# 目前進度：第9000張照片
# 目前進度：第9500張照片
# 目前進度：第10000張照片
# 目前進度：第10500張照片
# 目前進度：第11000張照片
# 目前進度：第11500張照片
# 目前進度：第12000張照片
# 目前進度：第12500張照片
# total case number: 12656
# 訓練集預測結果：
# average Dice score per case of kidney:  0.9608
# average recall of kidney:  0.9543
# average precision of kidney:  0.9698
# global dice score of kidney:  0.9542
# 花費時間(秒)：1515.652453660965

# %%
# st = time.time()

# preds = result[4]

# _ = evaluate_model(
#     image_dir = os.path.join(dataset_dir, 'test', 'images'), 
#     label_dir = os.path.join(dataset_dir, 'test', 'annotations_tumor as kidney'), 
#     checkpoints_path = 'DATA_0811_2\\WW600WL100\\\model_resnet50_unet\\resnet50_unet_padding0',
#     calculate_predicting_indicators = False,
#     output_predicted_result = True, 
#     segment_out_predicted_region_from_original_images = True, 
#     roi_name = 'kidney', 
#     preds = preds
# )

# ed = time.time()
# spend_time = ed - st
# print('花費時間(秒)：' + str(spend_time))
# print()
